# %% [markdown]
# ##### COMMON IMPORTS

# %%
import os
import sys
import asyncio

import pandas as pd


PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), "..", "..",".."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

# %% [markdown]
# ### GET INFO

# %% [markdown]
# ##### RECEVING CURRENT FUTURES ON MOEX

# %%
from app.infrastructure.services.futures import get_active_futures

await get_active_futures()
# Out:
# ready to load pickle
# can't load local pickle, forwarding to moex API.
# deleted old pickles
# saved fresh pickle
# loaded local pickle
#     ticker board    shortname  decimals  minstep lasttradedate sectype  \
# 0     AAH6  RFUD  AFRICA-3.26         2    0.010    2026-03-20      AA
# 1     AAM6  RFUD  AFRICA-6.26         2    0.010    2026-06-19      AA
# 2     AEH6  RFUD     AED-3.26         3    0.001    2026-03-19      AE
# 3     AEM6  RFUD     AED-6.26         3    0.001    2026-06-18      AE
# 4     AFH6  RFUD    AFLT-3.26         0    1.000    2026-03-19      AF
# ..     ...   ...          ...       ...      ...           ...     ...
# 414   XIM6  RFUD     XIA-6.26         2    0.010    2026-06-19      XI
# 415   YDH6  RFUD    YDEX-3.26         0    1.000    2026-03-19      YD
# 416   YDM6  RFUD    YDEX-6.26         0    1.000    2026-06-18      YD
# 417   ZCH6  RFUD    ZINC-3.26         1    0.500    2026-03-17      ZC
# 418   ZCM6  RFUD    ZINC-6.26         1    0.500    2026-06-16      ZC
#
#     assetcode  lotvolume  initialmargin
# 0      AFRICA          1         769.19
# 1      AFRICA          1         793.92
# 2         AED       1000        3216.94
# 3         AED       1000        3349.40
# 4        AFLT        100        1437.87
# ..        ...        ...            ...
# 414       XIA        100        6293.07
# 415      YDEX          1         852.06
# 416      YDEX          1         952.33
# 417      ZINC        100        3098.90
# 418      ZINC        100        3550.85
#
# [419 rows x 10 columns]
